# %%
import pandas as pd

# %%
data=pd.read_csv("matches.csv")

# %%
data.tail()
# Out:
#         id  season           city        date                  team1  \
# 751  11347    2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  11415    2019      Hyderabad  12-05-2019         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
data.tail(1)
# Out:
#         id  season       city        date           team1  \
# 755  11415    2019  Hyderabad  12-05-2019  Mumbai Indians
#
#                    team2     toss_winner toss_decision  result  dl_applied  \
# 755  Chennai Super Kings  Mumbai Indians           bat  normal           0
#
#              winner  win_by_runs  win_by_wickets player_of_match  \
# 755  Mumbai Indians            1               0       JJ Bumrah
#
#                                   venue      umpire1    umpire2      umpire3
# 755  Rajiv Gandhi Intl. Cricket Stadium  Nitin Menon  Ian Gould  Nigel Llong

# %%
data.shape[1]
# Out:
# 18

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.280423        3.350529
# std     3464.478148     3.366895    0.156630    23.466717        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
 data["winner"]
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 751                 Mumbai Indians
# 752                 Mumbai Indians
# 753                 Delhi Capitals
# 754            Chennai Super Kings
# 755                 Mumbai Indians
# Name: winner, Length: 756, dtype: object

# %%
type(data["winner"])
# Out:
# pandas.core.series.Series

# %%
data
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415    2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data[["team1","team2","winner"]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[1]
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            06-04-2017
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %%
data.iloc[0:3
         ]
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017       Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
data.iloc[1:10:3]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 7   8    2017     Indore  10-04-2017  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 1           0       Rising Pune Supergiant            0               7
# 4           0  Royal Challengers Bangalore           15               0
# 7           0              Kings XI Punjab            0               8
#
#   player_of_match                                    venue         umpire1  \
# ...

# %%
data.iloc[[1,3,5]]
# Out:
#    id  season       city        date                   team1  \
# 1   2    2017       Pune  06-04-2017          Mumbai Indians
# 3   4    2017     Indore  08-04-2017  Rising Pune Supergiant
# 5   6    2017  Hyderabad  09-04-2017           Gujarat Lions
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 3           0         Kings XI Punjab            0               6
# 5           0     Sunrisers Hyderabad            0               9
#
#   player_of_match                                      venue         umpire1  \
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
data.iloc[253,255]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_8416/1816916515.py in <module>
# ----> 1 data.iloc[253,255]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ...

# %%
data.iloc[[254,255]]
# Out:
#       id  season        city        date                 team1  \
# 254  255    2011     Kolkata  20-04-2011  Kochi Tuskers Kerala
# 255  256    2011  Chandigarh  21-04-2011       Kings XI Punjab
#
#                      team2            toss_winner toss_decision  result  \
# 254  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 255       Rajasthan Royals       Rajasthan Royals         field  normal
#
#      dl_applied                winner  win_by_runs  win_by_wickets  \
# 254           0  Kochi Tuskers Kerala            6               0
# 255           0       Kings XI Punjab           47               0
#
#       player_of_match                                       venue    umpire1  \
# 254  DPMD Jayawardene                                Eden Gardens  Aleem Dar
# 255          SE Marsh  Punjab Cricket Association Stadium, Mohali   S Asnani
#
#         umpire2 umpire3
# 254   RB Tiffin     NaN
# 255  PR Reiffel     NaN

# %%
data.iloc[:,[2,4,6]]
# Out:
#               city                        team1                  toss_winner
# 0        Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1             Pune               Mumbai Indians       Rising Pune Supergiant
# 2           Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3           Indore       Rising Pune Supergiant              Kings XI Punjab
# 4        Bangalore  Royal Challengers Bangalore  Royal Challengers Bangalore
# ..             ...                          ...                          ...
# 751         Mumbai        Kolkata Knight Riders               Mumbai Indians
# 752        Chennai          Chennai Super Kings          Chennai Super Kings
# 753  Visakhapatnam          Sunrisers Hyderabad               Delhi Capitals
# 754  Visakhapatnam               Delhi Capitals          Chennai Super Kings
# 755      Hyderabad               Mumbai Indians               Mumbai Indians
#
# [756 rows x 3 columns]

# %%
data
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415    2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
mask=data["city"]=="Rajkot"
mask2=data["season"]==2017

data[mask & mask2]
# Out:
#     id  season    city        date                        team1  \
# 2    3    2017  Rajkot  07-04-2017                Gujarat Lions
# 12  13    2017  Rajkot  14-04-2017       Rising Pune Supergiant
# 19  20    2017  Rajkot  18-04-2017  Royal Challengers Bangalore
# 25  26    2017  Rajkot  23-04-2017              Kings XI Punjab
# 33  34    2017  Rajkot  29-04-2017                Gujarat Lions
#
#                     team2            toss_winner toss_decision  result  \
# 2   Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 12          Gujarat Lions          Gujarat Lions         field  normal
# 19          Gujarat Lions          Gujarat Lions         field  normal
# 25          Gujarat Lions          Gujarat Lions         field  normal
# 33         Mumbai Indians          Gujarat Lions           bat     tie
#
#     dl_applied                       winner  win_by_runs  win_by_wickets  \
# 2            0        Kolkata Knight Riders            0              10
# ...

# %%
data[mask]
# Out:
#       id  season    city        date                        team1  \
# 2      3    2017  Rajkot  07-04-2017                Gujarat Lions
# 12    13    2017  Rajkot  14-04-2017       Rising Pune Supergiant
# 19    20    2017  Rajkot  18-04-2017  Royal Challengers Bangalore
# 25    26    2017  Rajkot  23-04-2017              Kings XI Punjab
# 33    34    2017  Rajkot  29-04-2017                Gujarat Lions
# 581  582    2016  Rajkot  14-04-2016      Rising Pune Supergiants
# 590  591    2016  Rajkot  21-04-2016                Gujarat Lions
# 594  595    2016  Rajkot  24-04-2016  Royal Challengers Bangalore
# 603  604    2016  Rajkot  01-05-2016              Kings XI Punjab
# 606  607    2016  Rajkot  03-05-2016                Gujarat Lions
#
#                      team2                  toss_winner toss_decision  result  \
# 2    Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 12           Gujarat Lions                Gujarat Lions         field  normal
# ...

# %% [markdown]
# data

# %%
mask=data["city"]=="Rajkot"
mask2=data["season"]==2017
mask3=data["winner"]=="Kolkata Knight Riders"
data[mask & mask2 & mask3]
# Out:
#    id  season    city        date          team1                  team2  \
# 2   3    2017  Rajkot  07-04-2017  Gujarat Lions  Kolkata Knight Riders
#
#              toss_winner toss_decision  result  dl_applied  \
# 2  Kolkata Knight Riders         field  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# 2  Kolkata Knight Riders            0              10         CA Lynn
#
#                                     venue      umpire1    umpire2 umpire3
# 2  Saurashtra Cricket Association Stadium  Nitin Menon  CK Nandan     NaN

# %%
def get_city_count(city):
    mask=data["city"]==city
    return data[mask]

# %%
get_city_count("Rajkot")
# Out:
#       id  season    city        date                        team1  \
# 2      3    2017  Rajkot  07-04-2017                Gujarat Lions
# 12    13    2017  Rajkot  14-04-2017       Rising Pune Supergiant
# 19    20    2017  Rajkot  18-04-2017  Royal Challengers Bangalore
# 25    26    2017  Rajkot  23-04-2017              Kings XI Punjab
# 33    34    2017  Rajkot  29-04-2017                Gujarat Lions
# 581  582    2016  Rajkot  14-04-2016      Rising Pune Supergiants
# 590  591    2016  Rajkot  21-04-2016                Gujarat Lions
# 594  595    2016  Rajkot  24-04-2016  Royal Challengers Bangalore
# 603  604    2016  Rajkot  01-05-2016              Kings XI Punjab
# 606  607    2016  Rajkot  03-05-2016                Gujarat Lions
#
#                      team2                  toss_winner toss_decision  result  \
# 2    Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 12           Gujarat Lions                Gujarat Lions         field  normal
# ...

# %%
import pandas as pd

# %%
data["winner"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9044/1109259233.py in <module>
# ----> 1 data["winner"].value_counts()
#
# NameError: name 'data' is not defined

# %%
data=pd.read_csv("matches.csv")

# %%
data
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415    2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
data["winner"].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
data["winner"].values_counts()index
# Out:
#   File "C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9044/1462627657.py", line 1
#     data["winner"].values_counts()index
#                                   ^
# SyntaxError: invalid syntax

# %%
data["winner"].values_counts().index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9044/2894507404.py in <module>
# ----> 1 data["winner"].values_counts().index
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'values_counts'

# %%
data["winner"].value_counts()index
# Out:
#   File "C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9044/1497794970.py", line 1
#     data["winner"].value_counts()index
#                                  ^
# SyntaxError: invalid syntax

# %%
data["winner"].value_counts().index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Delhi Capitals', 'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object')

# %%
data["winner"].value_counts().value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9044/3372202404.py in <module>
# ----> 1 data["winner"].value_counts().value
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
data["winner"].value_counts().values
# Out:
# array([109, 100,  92,  84,  82,  75,  67,  58,  29,  13,  12,  10,  10,
#          6,   5], dtype=int64)

# %%
data["team1"].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9044/2057118562.py in <module>
# ----> 1 data["team1"].value_count()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
data["team1"].value_counts()+data["team2"].value_counts()
# Out:
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# dtype: int64

# %%
(data["team1"].value_counts()+data["team2"].value_counts()).shape
# Out:
# (15,)

# %%
import matplotlib

# %%
data["winner"].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
data["winner"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
data["winner"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
data["winner"].value_counts().head().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415    2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
data["toss_decision"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
data["winner"].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
data["toss_decision"].value_counts()
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %%
data["win_by_runs"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.280423        3.350529
# std     3464.478148     3.366895    0.156630    23.466717        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000
