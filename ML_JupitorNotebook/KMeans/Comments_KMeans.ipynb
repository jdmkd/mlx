# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\A7x\ML\Comments.csv",usecols=["status_id","num_reactions","num_comments","num_shares","num_likes","num_loves","num_wows","num_hahas","num_sads","num_angrys"])

# %%
df
# Out:
#       status_id  num_reactions  num_comments  num_shares  num_likes  \
# 0             1            529           512         262        432
# 1             2            150             0           0        150
# 2             3            227           236          57        204
# 3             4            111             0           0        111
# 4             5            213             0           0        204
# ...         ...            ...           ...         ...        ...
# 7045       7046             89             0           0         89
# 7046       7047             16             0           0         14
# 7047       7048              2             0           0          1
# 7048       7049            351            12          22        349
# 7049       7050             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=3)

# %%
model.fit(df)
# Out:
# KMeans(n_clusters=3)

# %%
df['clusters']=model.labels_

# %%
df
# Out:
#       status_id  num_reactions  num_comments  num_shares  num_likes  \
# 0             1            529           512         262        432
# 1             2            150             0           0        150
# 2             3            227           236          57        204
# 3             4            111             0           0        111
# 4             5            213             0           0        204
# ...         ...            ...           ...         ...        ...
# 7045       7046             89             0           0         89
# 7046       7047             16             0           0         14
# 7047       7048              2             0           0          1
# 7048       7049            351            12          22        349
# 7049       7050             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys  clusters
# 0            92         3          1         1           0         1
# ...

# %%
df.to_csv(r"C:\A7x\ML\Comments_KMeans_clustered.csv")
