# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\\Users\\admin\\Downloads\\ML_JupitorNotebook\\matches.csv")
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415    2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
df.head(5)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.tail(1)
# Out:
#         id  season       city        date           team1  \
# 755  11415    2019  Hyderabad  12-05-2019  Mumbai Indians
#
#                    team2     toss_winner toss_decision  result  dl_applied  \
# 755  Chennai Super Kings  Mumbai Indians           bat  normal           0
#
#              winner  win_by_runs  win_by_wickets player_of_match  \
# 755  Mumbai Indians            1               0       JJ Bumrah
#
#                                   venue      umpire1    umpire2      umpire3
# 755  Rajiv Gandhi Intl. Cricket Stadium  Nitin Menon  Ian Gould  Nigel Llong

# %%
df.shape
# Out:
# (756, 18)

# %%
df.shape[0]
# Out:
# 756

# %%
df.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.280423        3.350529
# std     3464.478148     3.366895    0.156630    23.466717        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
df["winner"]
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 751                 Mumbai Indians
# 752                 Mumbai Indians
# 753                 Delhi Capitals
# 754            Chennai Super Kings
# 755                 Mumbai Indians
# Name: winner, Length: 756, dtype: object

# %%
df[["team1","team2","winner"]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df.iloc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              05-04-2017
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
df.iloc[0:10]
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  09-04-2017                Gujarat Lions
# 6   7    2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7   8    2017     Indore  10-04-2017  Royal Challengers Bangalore
# 8   9    2017       Pune  11-04-2017             Delhi Daredevils
# 9  10    2017     Mumbai  12-04-2017          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
df.iloc[0:10:2]
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 6   7    2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 8   9    2017       Pune  11-04-2017             Delhi Daredevils
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# 6               Mumbai Indians               Mumbai Indians         field
# 8       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.iloc[[111,222,333,444,555,666]]
# Out:
#        id  season       city        date                        team1  \
# 111   112    2008    Kolkata  25-05-2008              Kings XI Punjab
# 222   223    2010     Jaipur  14-04-2010             Rajasthan Royals
# 333   334    2012    Chennai  21-04-2012             Rajasthan Royals
# 444   445    2013     Ranchi  15-05-2013                Pune Warriors
# 555   556    2015     Mumbai  05-05-2015             Delhi Daredevils
# 666  7924    2018  Bengaluru  01-05-2018  Royal Challengers Bangalore
#
#                            team2            toss_winner toss_decision  result  \
# 111        Kolkata Knight Riders        Kings XI Punjab           bat  normal
# 222  Royal Challengers Bangalore       Rajasthan Royals           bat  normal
# 333          Chennai Super Kings       Rajasthan Royals           bat  normal
# 444        Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 555               Mumbai Indians       Delhi Daredevils           bat  normal
# ...

# %%
df.iloc[:,[1,2,4,5,10]]
# Out:
#      season           city                        team1  \
# 0      2017      Hyderabad          Sunrisers Hyderabad
# 1      2017           Pune               Mumbai Indians
# 2      2017         Rajkot                Gujarat Lions
# 3      2017         Indore       Rising Pune Supergiant
# 4      2017      Bangalore  Royal Challengers Bangalore
# ..      ...            ...                          ...
# 751    2019         Mumbai        Kolkata Knight Riders
# 752    2019        Chennai          Chennai Super Kings
# 753    2019  Visakhapatnam          Sunrisers Hyderabad
# 754    2019  Visakhapatnam               Delhi Capitals
# 755    2019      Hyderabad               Mumbai Indians
#
#                            team2                       winner
# 0    Royal Challengers Bangalore          Sunrisers Hyderabad
# 1         Rising Pune Supergiant       Rising Pune Supergiant
# 2          Kolkata Knight Riders        Kolkata Knight Riders
# ...

# %%
df["city"]=="Bangalore"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 751    False
# 752    False
# 753    False
# 754    False
# 755    False
# Name: city, Length: 756, dtype: bool

# %%
d=df["city"]=="Bangalore"

# %%
df[d]
# Out:
#       id  season       city        date                        team1  \
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 11    12    2017  Bangalore  14-04-2017  Royal Challengers Bangalore
# 16    17    2017  Bangalore  16-04-2017       Rising Pune Supergiant
# 29    30    2017  Bangalore  27-04-2017  Royal Challengers Bangalore
# 41    42    2017  Bangalore  05-05-2017              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 616  617    2016  Bangalore  11-05-2016  Royal Challengers Bangalore
# 619  620    2016  Bangalore  14-05-2016  Royal Challengers Bangalore
# 625  626    2016  Bangalore  18-05-2016  Royal Challengers Bangalore
# 632  633    2016  Bangalore  24-05-2016                Gujarat Lions
# 635  636    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
d2=df["season"]==2017
df[d & d2]
# Out:
#     id  season       city        date                        team1  \
# 4    5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 11  12    2017  Bangalore  14-04-2017  Royal Challengers Bangalore
# 16  17    2017  Bangalore  16-04-2017       Rising Pune Supergiant
# 29  30    2017  Bangalore  27-04-2017  Royal Challengers Bangalore
# 41  42    2017  Bangalore  05-05-2017              Kings XI Punjab
# 44  45    2017  Bangalore  07-05-2017  Royal Challengers Bangalore
# 56  57    2017  Bangalore  17-05-2017          Sunrisers Hyderabad
# 57  58    2017  Bangalore  19-05-2017        Kolkata Knight Riders
#
#                           team2                  toss_winner toss_decision  \
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 11               Mumbai Indians               Mumbai Indians         field
# 16  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df[d & d2].shape
# Out:
# (8, 18)

# %%
def get_city_metch_count(city):
    d=df["city"]==city
    return df[d]

# %%
get_city_metch_count("Rajkot")
# Out:
#       id  season    city        date                        team1  \
# 2      3    2017  Rajkot  07-04-2017                Gujarat Lions
# 12    13    2017  Rajkot  14-04-2017       Rising Pune Supergiant
# 19    20    2017  Rajkot  18-04-2017  Royal Challengers Bangalore
# 25    26    2017  Rajkot  23-04-2017              Kings XI Punjab
# 33    34    2017  Rajkot  29-04-2017                Gujarat Lions
# 581  582    2016  Rajkot  14-04-2016      Rising Pune Supergiants
# 590  591    2016  Rajkot  21-04-2016                Gujarat Lions
# 594  595    2016  Rajkot  24-04-2016  Royal Challengers Bangalore
# 603  604    2016  Rajkot  01-05-2016              Kings XI Punjab
# 606  607    2016  Rajkot  03-05-2016                Gujarat Lions
#
#                      team2                  toss_winner toss_decision  result  \
# 2    Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 12           Gujarat Lions                Gujarat Lions         field  normal
# ...

# %%
df["winner"].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
df["team1"].value_counts()
# Out:
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Delhi Capitals                   6
# Name: team1, dtype: int64

# %%
df["team2"].value_counts()
# Out:
# Royal Challengers Bangalore    95
# Kolkata Knight Riders          95
# Delhi Daredevils               89
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Chennai Super Kings            75
# Sunrisers Hyderabad            45
# Deccan Chargers                32
# Pune Warriors                  26
# Gujarat Lions                  16
# Delhi Capitals                 10
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team2, dtype: int64

# %%
df["team1"].value_counts() + df["team2"].value_counts()
# Out:
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# dtype: int64

# %%
import matplotlib

# %%
df["winner"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["winner"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["winner"].value_counts().head().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["toss_decision"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
df["win_by_wickets"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>
