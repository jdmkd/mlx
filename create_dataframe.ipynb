# %%
import pandas as pd

# %%
data={"rno":[1,2,3,4,5],"name":["k","r","u","p","a"],"city":["abad","baroda","rajkot","pune","surat"]}

# %%
data
# Out:
# {'rno': [1, 2, 3, 4, 5],
#  'name': ['k', 'r', 'u', 'p', 'a'],
#  'city': ['abad', 'baroda', 'rajkot', 'pune', 'surat']}

# %%
mask=pd.DataFrame(data)

# %%
mask
# Out:
#    rno name    city
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
print(mask)
# Out:
#    rno name    city
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
mask.rename(columns={"city":"place"})
# Out:
#    rno name   place
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
mask.rename(columns={"name":"Name"},inplace=True)

# %%
mask
# Out:
#    rno Name    city
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
mask.rename(columns={"city":"place"},inplace=True)

# %%
mask.insert(loc=3,column="state",value=["guju","guju","mp","up","pk"])

# %%
mask
# Out:
#    rno Name    city state
# 0    1    k    abad  guju
# 1    2    r  baroda  guju
# 2    3    u  rajkot    mp
# 3    4    p    pune    up
# 4    5    a   surat    pk

# %%
mask.rename(columns={"states":"state"},inplace=True)

# %%
mask
# Out:
#    rno Name    city state
# 0    1    k    abad  guju
# 1    2    r  baroda  guju
# 2    3    u  rajkot    mp
# 3    4    p    pune    up
# 4    5    a   surat    pk

# %%
data
# Out:
# {'rno': [1, 2, 3, 4, 5],
#  'name': ['k', 'r', 'u', 'p', 'a'],
#  'city': ['abad', 'baroda', 'rajkot', 'pune', 'surat']}

# %%
mask
# Out:
#    rno Name    city state
# 0    1    k    abad  guju
# 1    2    r  baroda  guju
# 2    3    u  rajkot    mp
# 3    4    p    pune    up
# 4    5    a   surat    pk

# %%
mask.drop(["state"],axis=1,inplace=True)

# %%
mask
# Out:
#    rno Name    city
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
mask.drop(mask.index[0],axis=0,inplace=False)
# Out:
#    rno Name    city
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
mask
# Out:
#    rno Name    city
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
mask
# Out:
#    rno Name   place
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
mask.append(pd.DataFrame([[6,"s","rajkot"]],columns=mask.columns),ignore_index=True)
# Out:
#    rno Name   place
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat
# 5    6    s  rajkot

# %% [markdown]
# mask.append(pd.DataFrame([[7,"v","abad"]],columns=mask.columns),ignore_index=False)

# %%
mask
# Out:
#    rno Name   place
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
mask.append(pd.DataFrame([[6,"s","rajkot"]],columns=mask.columns),ignore_index=True)
# Out:
#    rno Name   place
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat
# 5    6    s  rajkot

# %%
df=mask[['rno','Name','place']].copy()
df
# Out:
#    rno Name   place
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %% [markdown]
# df

# %%
df
# Out:
#    rno Name   place
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
mask
# Out:
#    rno Name   place
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat

# %%
df
# Out:
#    rno Name   place
# 0    1    k    abad
# 1    2    r  baroda
# 2    3    u  rajkot
# 3    4    p    pune
# 4    5    a   surat
